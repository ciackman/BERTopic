# %% [markdown]
# # **Tutorial** - Dynamic Topic Modeling with Trump's Tweets
# (last updated 11-09-2022)
#
# In this tutorial we will be using Dynamic Topic Modeling with BERTopic to visualize how topics in Trump's Tweets have evolved over time. These topics will be visualized and thoroughly explored.
#
# ## Dynamic Topic Models
# Dynamic topic models can be used to analyze the evolution of topics of a collection of documents over time.
#
# <br>
#
# <img src="https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png" width="40%">

# %% [markdown]
# # Enabling the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# [Reference](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# # Installing BERTopic
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# # **Data**
# For this tutorial, we will be needing to extract all Trump's Tweet from his @realDonalTrump account. We will be removing all retweet and focus on his original tweets.
#
# Moreover, since we are looking at his tweets over time, we will be saving all timestamps related to his tweets.

# %%
import re
import pandas as pd
from datetime import datetime

# Load data
trump = pd.read_csv('https://drive.google.com/uc?export=download&id=1xRKHaP-QwACMydlDnyFPEaFdtskJuBa6')

# %%
trump[:10]
# Out:
#                     id                                               text  \
# 0    98454970654916608  Republicans and Democrats have both created ou...
# 1  1234653427789070336  I was thrilled to be back in the Great city of...
# 2  1218010753434820614  RT @CBS_Herridge: READ: Letter to surveillance...
# 3  1304875170860015617  The Unsolicited Mail In Ballot Scam is a major...
# 4  1218159531554897920  RT @MZHemingway: Very friendly telling of even...
# 5  1217962723234983937  RT @WhiteHouse: President @realDonaldTrump ann...
# 6  1223640662689689602  Getting a little exercise this morning! https:...
# 7  1319501865625784320                            https://t.co/4qwCKQOiOw
# 8  1319500520126664705                            https://t.co/VlEu8yyovv
# 9  1319500501269041154                            https://t.co/z5CRqHO8vg
#
#   isRetweet isDeleted              device  favorites  retweets  \
# 0         f         f           TweetDeck         49       255
# 1         f         f  Twitter for iPhone      73748     17404
# 2         t         f  Twitter for iPhone          0      7396
# 3         f         f  Twitter for iPhone      80527     23502
# 4         t         f  Twitter for iPhone          0      9081
# 5         t         f  Twitter for iPhone          0     25048
# 6         f         f  Twitter for iPhone     285863     30209
# 7         f         f  Twitter for iPhone     130822     19127
# 8         f         f  Twitter for iPhone     153446     20275
# 9         f         f  Twitter for iPhone     102150     14815
#
#                   date isFlagged
# 0  2011-08-02 18:07:48         f
# 1  2020-03-03 01:34:50         f
# 2  2020-01-17 03:22:47         f
# 3  2020-09-12 20:10:58         f
# 4  2020-01-17 13:13:59         f
# 5  2020-01-17 00:11:56         f
# 6  2020-02-01 16:14:02         f
# 7  2020-10-23 04:52:14         f
# 8  2020-10-23 04:46:53         f
# 9  2020-10-23 04:46:49         f

# %% [markdown]
# ##**Data Processing**

# %%
# Rimuove i link (URL) da ogni testo nella colonna "text" del dataframe "trump"
trump.text = trump.apply(lambda row: re.sub(r"http\S+", "", row.text).lower(), 1)
    # trump.apply(...): Applica una funzione a tutte le righe del dataframe "trump".
    # lambda row: ...: Questa è un'espressione lambda che definisce una funzione anonima con un argomento row. La funzione prende ogni riga (row) come input.
    # re.sub(r"http\S+", "", row.text) sostituisce tutti gli URL con una stringa vuota.
    # .lower() converte il testo risultante in minuscolo.
    # , 1): Il secondo argomento di apply è il numero di assi su cui applicare la funzione. 1 indica che la funzione deve essere applicata lungo le righe.
trump[7:10]
#trump[]
# Out:
#                     id text isRetweet isDeleted              device  \
# 7  1319501865625784320              f         f  Twitter for iPhone
# 8  1319500520126664705              f         f  Twitter for iPhone
# 9  1319500501269041154              f         f  Twitter for iPhone
#
#    favorites  retweets                 date isFlagged
# 7     130822     19127  2020-10-23 04:52:14         f
# 8     153446     20275  2020-10-23 04:46:53         f
# 9     102150     14815  2020-10-23 04:46:49         f

# %%
# Rimuove le menzioni agli utenti Twitter (che iniziano con "@") da ogni testo nella colonna "text" del dataframe "trump"
trump.text = trump.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.text.split())), 1)
    # row.text.split(): Questa parte prende il testo dalla colonna "text" della riga corrente (row) e lo suddivide in una lista di parole
    # lambda x: x[0]!="@": Questa è una funzione lambda che prende una parola (x) come input e restituisce True se il primo carattere della parola non è "@" e False altrimenti
    # filter restituisce solo gli elementi della lista per i quali la funzione lambda x: x[0]!="@" restituisce True
    # " ".join(...): Infine, questa parte del codice riunisce le parole rimanenti in una stringa, separando ogni parola con uno spazio. Questo è fatto utilizzando il metodo join
trump
# Out:
#                         id                                               text  \
# 0        98454970654916608  republicans and democrats have both created ou...
# 1      1234653427789070336  i was thrilled to be back in the great city of...
# 2      1218010753434820614  rt read: letter to surveillance court obtained...
# 3      1304875170860015617  the unsolicited mail in ballot scam is a major...
# 4      1218159531554897920  rt very friendly telling of events here about ...
# ...                    ...                                                ...
# 56566  1319485303363571714  rt i don’t know why thinks he can continue to ...
# 56567  1319484210101379072  rt president excels at communicating directly ...
# 56568  1319444420861829121  rt live: presidential debate #debates2020 text...
# 56569  1319384118849949702  just signed an order to support the workers of...
# 56570  1319345719829008387  suburban women want safety &amp; security. joe...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 0             f         f           TweetDeck         49       255
# 1             f         f  Twitter for iPhone      73748     17404
# 2             t         f  Twitter for iPhone          0      7396
# 3             f         f  Twitter for iPhone      80527     23502
# 4             t         f  Twitter for iPhone          0      9081
# ...         ...       ...                 ...        ...       ...
# 56566         t         f  Twitter for iPhone          0     20683
# 56567         t         f  Twitter for iPhone          0      9869
# 56568         t         f  Twitter for iPhone          0      8197
# 56569         f         f  Twitter for iPhone     176289     36001
# 56570         f         f  Twitter for iPhone      95169     19545
#
#                       date isFlagged
# 0      2011-08-02 18:07:48         f
# 1      2020-03-03 01:34:50         f
# 2      2020-01-17 03:22:47         f
# 3      2020-09-12 20:10:58         f
# 4      2020-01-17 13:13:59         f
# ...                    ...       ...
# 56566  2020-10-23 03:46:25         f
# 56567  2020-10-23 03:42:05         f
# 56568  2020-10-23 01:03:58         f
# 56569  2020-10-22 21:04:21         f
# 56570  2020-10-22 18:31:46         f
#
# [56571 rows x 9 columns]

# %%
# Rimuove i caratteri non alfabetici da ogni testo nella colonna "text" del dataframe "trump"
trump.text = trump.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.text).split()), 1)
  # re.sub("[^a-zA-Z]+", " ", row.text): utilizza la funzione re.sub del modulo re (espressioni regolari) per sostituire ogni sequenza di caratteri non alfabetici con uno spazio nella colonna "text" della riga corrente (row).
    # In altre parole, rimuove tutti i caratteri non alfabetici, lasciando solo le parole.
  # .split(): Questa parte suddivide il testo risultante in una lista di parole utilizzando gli spazi come delimitatori.
  # " ".join(...): Infine, questa parte riunisce le parole rimanenti in una stringa
trump
# Out:
#                         id                                               text  \
# 0        98454970654916608  republicans and democrats have both created ou...
# 1      1234653427789070336  i was thrilled to be back in the great city of...
# 2      1218010753434820614  rt read letter to surveillance court obtained ...
# 3      1304875170860015617  the unsolicited mail in ballot scam is a major...
# 4      1218159531554897920  rt very friendly telling of events here about ...
# ...                    ...                                                ...
# 56566  1319485303363571714  rt i don t know why thinks he can continue to ...
# 56567  1319484210101379072  rt president excels at communicating directly ...
# 56568  1319444420861829121   rt live presidential debate debates text vote to
# 56569  1319384118849949702  just signed an order to support the workers of...
# 56570  1319345719829008387  suburban women want safety amp security joe bi...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 0             f         f           TweetDeck         49       255
# 1             f         f  Twitter for iPhone      73748     17404
# 2             t         f  Twitter for iPhone          0      7396
# 3             f         f  Twitter for iPhone      80527     23502
# 4             t         f  Twitter for iPhone          0      9081
# ...         ...       ...                 ...        ...       ...
# 56566         t         f  Twitter for iPhone          0     20683
# 56567         t         f  Twitter for iPhone          0      9869
# 56568         t         f  Twitter for iPhone          0      8197
# 56569         f         f  Twitter for iPhone     176289     36001
# 56570         f         f  Twitter for iPhone      95169     19545
#
#                       date isFlagged
# 0      2011-08-02 18:07:48         f
# 1      2020-03-03 01:34:50         f
# 2      2020-01-17 03:22:47         f
# 3      2020-09-12 20:10:58         f
# 4      2020-01-17 13:13:59         f
# ...                    ...       ...
# 56566  2020-10-23 03:46:25         f
# 56567  2020-10-23 03:42:05         f
# 56568  2020-10-23 01:03:58         f
# 56569  2020-10-22 21:04:21         f
# 56570  2020-10-22 18:31:46         f
#
# [56571 rows x 9 columns]

# %%
# Filtra le righe del dataframe "trump" mantenendo solo quelle che non sono retweet e che hanno un testo non vuoto
trump = trump.loc[(trump.isRetweet == "f") & (trump.text != ""), :]
    #Filtra le righe del dataframe, mantenendo solo quelle che non sono retweet (isRetweet == "f") e che hanno un testo non vuoto (text != "").
trump
# Out:
#                         id                                               text  \
# 0        98454970654916608  republicans and democrats have both created ou...
# 1      1234653427789070336  i was thrilled to be back in the great city of...
# 3      1304875170860015617  the unsolicited mail in ballot scam is a major...
# 6      1223640662689689602             getting a little exercise this morning
# 14     1215247978966986752                                    thank you elise
# ...                    ...                                                ...
# 56555  1213078681750573056  iran never won a war but never lost a negotiation
# 56559  1212177432452698115  thank you to the washington examiner the list ...
# 56560  1212175360093229056  one of my greatest honors was to have gotten c...
# 56569  1319384118849949702  just signed an order to support the workers of...
# 56570  1319345719829008387  suburban women want safety amp security joe bi...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 0             f         f           TweetDeck         49       255
# 1             f         f  Twitter for iPhone      73748     17404
# 3             f         f  Twitter for iPhone      80527     23502
# 6             f         f  Twitter for iPhone     285863     30209
# 14            f         f  Twitter for iPhone      48510     11608
# ...         ...       ...                 ...        ...       ...
# 56555         f         f  Twitter for iPhone     303007     57253
# 56559         f         f  Twitter for iPhone      35044      9213
# 56560         f         f  Twitter for iPhone      56731     12761
# 56569         f         f  Twitter for iPhone     176289     36001
# 56570         f         f  Twitter for iPhone      95169     19545
#
#                       date isFlagged
# 0      2011-08-02 18:07:48         f
# 1      2020-03-03 01:34:50         f
# 3      2020-09-12 20:10:58         f
# 6      2020-02-01 16:14:02         f
# 14     2020-01-09 12:24:31         f
# ...                    ...       ...
# 56555  2020-01-03 12:44:30         f
# 56559  2020-01-01 01:03:15         f
# 56560  2020-01-01 00:55:01         f
# 56569  2020-10-22 21:04:21         f
# 56570  2020-10-22 18:31:46         f
#
# [45355 rows x 9 columns]

# %%
trump
# Out:
#                         id                                               text  \
# 0        98454970654916608  republicans and democrats have both created ou...
# 1      1234653427789070336  i was thrilled to be back in the great city of...
# 3      1304875170860015617  the unsolicited mail in ballot scam is a major...
# 6      1223640662689689602             getting a little exercise this morning
# 14     1215247978966986752                                    thank you elise
# ...                    ...                                                ...
# 56555  1213078681750573056  iran never won a war but never lost a negotiation
# 56559  1212177432452698115  thank you to the washington examiner the list ...
# 56560  1212175360093229056  one of my greatest honors was to have gotten c...
# 56569  1319384118849949702  just signed an order to support the workers of...
# 56570  1319345719829008387  suburban women want safety amp security joe bi...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 0             f         f           TweetDeck         49       255
# 1             f         f  Twitter for iPhone      73748     17404
# 3             f         f  Twitter for iPhone      80527     23502
# 6             f         f  Twitter for iPhone     285863     30209
# 14            f         f  Twitter for iPhone      48510     11608
# ...         ...       ...                 ...        ...       ...
# 56555         f         f  Twitter for iPhone     303007     57253
# 56559         f         f  Twitter for iPhone      35044      9213
# 56560         f         f  Twitter for iPhone      56731     12761
# 56569         f         f  Twitter for iPhone     176289     36001
# 56570         f         f  Twitter for iPhone      95169     19545
#
#                       date isFlagged
# 0      2011-08-02 18:07:48         f
# 1      2020-03-03 01:34:50         f
# 3      2020-09-12 20:10:58         f
# 6      2020-02-01 16:14:02         f
# 14     2020-01-09 12:24:31         f
# ...                    ...       ...
# 56555  2020-01-03 12:44:30         f
# 56559  2020-01-01 01:03:15         f
# 56560  2020-01-01 00:55:01         f
# 56569  2020-10-22 21:04:21         f
# 56570  2020-10-22 18:31:46         f
#
# [45355 rows x 9 columns]

# %%
# Estrae le colonne "date" e "text" dal dataframe filtrato "trump" e le converte in liste
timestamps = trump.date.to_list()
tweets = trump.text.to_list()

# %%
#timestamps[0]
tweets[3]
# Out:
# 'getting a little exercise this morning'

# %% [markdown]
# # **Dynamic Topic Modeling**

# %% [markdown]
# ## Basic Topic Model
# To perform Dynamic Topic Modeling with BERTopic we will first need to create a basic topic model using all tweets. The temporal aspect will be ignored as we are, for now, only interested in the topics that reside in those tweets.

# %%
from bertopic import BERTopic
topic_model = BERTopic(min_topic_size=35,  # Questo parametro rappresenta la dimensione minima accettabile per un argomento (topic). Gli argomenti con un numero di documenti al di sotto di questa soglia saranno considerati troppo piccoli
                       verbose=True)       # il modello fornirà informazioni dettagliate sull'avanzamento e su altre metriche durante l'addestramento o l'uso del modello

# %%
# Questa è la funzione di BERTopic che addestra il modello e allo stesso tempo restituisce l'assegnazione dei topic ai documenti
topics, _ = topic_model.fit_transform(tweets)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/1418 [00:00<?, ?it/s]
# 2023-11-14 11:29:27,038 - BERTopic - Transformed documents to Embeddings
# 2023-11-14 11:30:37,051 - BERTopic - Reduced dimensionality
# 2023-11-14 11:30:42,134 - BERTopic - Clustered reduced embeddings

# %% [markdown]
# We can then extract most frequent topics:

# %%
freq = topic_model.get_topic_info(); freq.head(10)

# Guardate il cluster -1, cos'è?
# Guardate il cluster 0, cosa rappresenta?
# Tenete in considerazione che qui non vi è alcuna customizzazione del modello
# Out:
#    Topic  Count                                   Name  \
# 0     -1  14928                        -1_the_to_of_is
# 1      0   3160           0_run_president_trump_donald
# 2      1   1983            1_crowd_carolina_thank_join
# 3      2   1077       2_border_wall_mexico_immigration
# 4      3    830          3_china_tariffs_trade_chinese
# 5      4    807         4_hotel_chicago_tower_building
# 6      5    658  5_obamacare_healthcare_repeal_website
# 7      6    629       6_golf_course_scotland_turnberry
# 8      7    620          7_hillary_clinton_crooked_she
# 9      8    584                        8_amp_you_it_to
#
#                                       Representation  \
# 0        [the, to, of, is, and, on, you, he, it, in]
# 1  [run, president, trump, donald, mr, please, ne...
# 2  [crowd, carolina, thank, join, rally, iowa, pe...
# 3  [border, wall, mexico, immigration, security, ...
# 4  [china, tariffs, trade, chinese, us, farmers, ...
# 5  [hotel, chicago, tower, building, sign, trump,...
# 6  [obamacare, healthcare, repeal, website, premi...
# 7  [golf, course, scotland, turnberry, club, link...
# 8  [hillary, clinton, crooked, she, bernie, her, ...
# 9  [amp, you, it, to, are, we, great, for, will, ...
#
#                                  Representative_Docs
# 0  [that fema our military and our first responde...
# 1  [schuetzkatie please hear my prayers and run f...
# 2  [iowa was amazing today great crowd great peop...
# 3  [our southern border is under siege congress m...
# 4  [this money will come from the massive tariffs...
# 5  [trump int l hotel amp tower chicago is one of...
# 6  [it was a great day for the united states of a...
# 7  [the scotland golf course in aberdeen is open ...
# 8  [i said that crooked hillary clinton is not qu...
# 9  [a full amp complete endorsement for who is do...

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_model.get_topic(-1)
# Out:
# [('the', 0.005576520340343325),
#  ('to', 0.005330163340520046),
#  ('of', 0.005241214500153621),
#  ('is', 0.005140525457172667),
#  ('and', 0.005113127268812148),
#  ('on', 0.004954694657684864),
#  ('you', 0.004853916589513333),
#  ('he', 0.004776724929946714),
#  ('it', 0.00465325929719414),
#  ('in', 0.004638177327950174)]

# %%
topic_model.get_topic(0)
# Out:
# [('run', 0.02687959634277334),
#  ('president', 0.023224131122200984),
#  ('trump', 0.018248166302449614),
#  ('donald', 0.015842814681196974),
#  ('mr', 0.015594724585778603),
#  ('please', 0.015231150525353997),
#  ('need', 0.013542349167867458),
#  ('you', 0.01340259293385347),
#  ('vote', 0.012924489111276622),
#  ('needs', 0.011680549851356787)]

# %%
topic_model.get_topic(4)
# Out:
# [('hotel', 0.0519907181696461),
#  ('chicago', 0.0396099517725186),
#  ('tower', 0.03820750414524775),
#  ('building', 0.023311485908249302),
#  ('sign', 0.020856459516392898),
#  ('trump', 0.01701912067473535),
#  ('luxury', 0.016817974378446895),
#  ('vegas', 0.016106297172173455),
#  ('hotels', 0.01587512235682698),
#  ('nyc', 0.015345417433933544)]

# %% [markdown]
# We can visualize the basic topics that were created with the Intertopic Distance Map. This allows us to judge visually whether the basic topics are sufficient before proceeding to creating the topics over time.

# %% [markdown]
50,"debt | ceiling | trillion | budget | deficit",153],[51,"stock | market | dow | high | since",149],[52,"makeamericagreatagain | trump | trumpforpresident | america | needs",145],[53,"debate | debates | drudge | won | polls",145],[54,"anarchists | portland | protesters | antifa | minneapolis",143],[55,"coronavirus | virus | covid | china | deaths",142],[56,"true | so | sadly | sooooo | but",142],[57,"collusion | russia | hunt | witch | russian",141],[58,"israel | peace | jerusalem | jewish | tlaib",141],[59,"warming | global | climate | freezing | cold",131],[60,"schiff | whistleblower | adam | shifty | call",131],[61,"cuomo | mayor | york | nyc | governor",130],[62,"fed | reserve | rates | inflation | federal",126],[63,"tweets | twitter | tweet | followers | ...

# %% [markdown]
# ## Topics over Time
# Before we start with the Dynamic Topic Modeling step, it is important that you are satisfied with the topics that were created previously. We are going to be using those specific topics as a base for Dynamic Topic Modeling.
#
# Thus, this step will essentially show you how the topics that were defined previously have evolved over time.

# %% [markdown]
# There are a few important parameters that you should take note of, namely:
#
# * `docs`
#   * These are the tweets that we are using
# * `timestamps`
#   * The timestamp of each tweet/document
# * `global_tuning`
#   * Whether to average the topic representation of a topic at time *t* with its global topic representation
# * `evolution_tuning`
#   * Whether to average the topic representation of a topic at time *t* with the topic representation of that topic at time *t-1*
# * `nr_bins`
#   * The number of bins to put our timestamps into. It is computationally inefficient to extract the topics at thousands of different timestamps. Therefore, it is advised to keep this value below 20.

# %%
topics_over_time = topic_model.topics_over_time(docs=tweets,
                                                timestamps=timestamps,
                                                global_tuning=True,     # media della topic representation al tempo t con con la topic repr. glob
                                                evolution_tuning=True,  # media della topic representation al tempo t con quella a t-1 (è una ponderata)
                                                nr_bins=20)
# Out:
# 20it [00:10,  1.83it/s]

# %% [markdown]
# ## Visualize Topics over Time
# After having created our `topics_over_time`, we will have to visualize those topics as accessing them becomes a bit more difficult with the added temporal dimension.
#
# To do so, we are going to visualize the distribution of topics over time based on their frequency. Doing so allows us to see how the topics have evolved over time. Make sure to hover over any point to see how the topic representation at time *t* differs from the global topic representation.

# %%
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="27ca301e-e466-4453-92cc-1629f8a5b753" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27ca301e-e466-4453-92cc-1629f8a5b753")) {                    Plotly.newPlot(                        "27ca301e-e466-4453-92cc-1629f8a5b753",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: execute, imagination, donald, step, inexplicable","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: shouldtrumprun, instance, usually, solved, solution","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: businesspeople, vendetta, considers, cont, president","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: brettmdecker, advantageous, invoking, nonpolitical, need","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: run, president, mr, trump, thanks","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: run, president, trump, you, mr","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: run, president, please, trump, mr","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: run, president, please, trump, mr","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: run, president, trump, donald, mr","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: trump, president, donald, run, need","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: trump, president, america, mr, crookedhillary","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: surrogates, eazymf, presidency, confirmgorsuch, economists","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: presidency, retaking, outlines, orator, rust","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: triumphs, drawing, saying, sophisticated, lynch","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: president, trump, dream, indicators, run","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: rt, president, steve, trump, know","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: objectively, outmastered, amash, arguably, sabato","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: vote, president, woodrow, morano, princeton"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_run_president_trump_donald","x":["2009-04-30T12:30:07.596999","2011-02-03T19:37:55.449999","2011-09-05T03:52:25.600000","2012-04-05T12:06:55.750000","2012-11-04T20:21:25.900000","2013-06-06T04:35:56.049999","2014-01-05T12:50:26.200000","2014-08-06T21:04:56.350000","2015-03-08T05:19:26.500000","2015-10-07T13:33:56.649999","2016-05-07T21:48:26.800000","2016-12-07T06:02:56.950000","2017-07-08T14:17:27.100000","2018-02-06T22:31:57.249999","2018-09-08T06:46:27.400000","2019-04-09T15:00:57.550000","2019-11-08T23:15:27.700000","2020-06-09T07:29:57.849999"],"y":[7,2,14,17,148,345,466,777,997,249,58,7,5,4,16,21,11,16],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: sheep, contest, counting, enter, trip","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: speech, cpac, dc, acn, foxnewsinsider","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: speaking, jose, san, florida, texas","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: convention, speech, sarasota, liberty, university","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: cpac, speech, crowd, michigan, charlotte","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: summit, iowa, crowd, leadership, keynoting","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: speech, cpac, johnny, forward, arizona","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: i ...

# %% [markdown]
# ## **Customizzazione del Modello**

# %% [markdown]
# # Step 1: Embedding

# %%
from sentence_transformers import SentenceTransformer

# Pre-calculate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2") # Trasformer visto su Hugging face in precedenza
embeddings = embedding_model.encode(tweets,
                                    show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1418 [00:00<?, ?it/s]

# %% [markdown]
# # Step 2: Dimensionality Reduction

# %% [markdown]
# ## **Preventing Stochastic Behavior**
# In BERTopic, we generally use a dimensionality reduction algorithm to reduce the size of the embeddings. This is done to prevent the [curse of dimensionality](https://en.wikipedia.org/wiki/Curse_of_dimensionality) to a certain degree.
#
# As a default, this is done with [UMAP](https://github.com/lmcinnes/umap) which is an incredible algorithm for reducing dimensional space. However, by default, it shows stochastic behavior which creates different results each time you run it. To prevent that, we will need to set a `random_state` of the model before passing it to BERTopic.
#
# As a result, we can now fully reproduce the results each time we run the model.

# %%
from umap import UMAP

umap_model = UMAP(n_neighbors=15,   # numero di punti per la costruzione del grafo iniziale
                  n_components=5,   # specifica la dimensione dello spazio ridotto in cui vengono proiettati i dati durante la riduzione dimensionale.
                  min_dist=0.0,     # distanza minima tra i punti
                  metric='cosine',  # metrica
                  random_state=42)  # per avere stessi risultati in caso di re-run

# %% [markdown]
# # Step 3: Clustering

# %%
from hdbscan import HDBSCAN

hdbscan_model = HDBSCAN(min_cluster_size=150,            # un gruppo di punti dovrà contenere almeno 150 elementi per essere considerato un cluster
                        metric='euclidean',
                        cluster_selection_method='eom',  # "Excess of Mass". Questo metodo cerca di trovare il livello di gerarchia in cui c'è un eccesso di massa rispetto alle regioni circostanti
                        prediction_data=True)            # calcolerà e manterrà informazioni aggiuntive utili per le previsioni future, ad esempio quando nuovi dati vengono aggiunti al modello senza dover ricalcolare tutto da capo

# %% [markdown]
# # Step 4: Tokenization

# %% [markdown]
# ## **Improving Default Representation**
# The default representation of topics is calculated through [c-TF-IDF](https://maartengr.github.io/BERTopic/algorithm/algorithm.html#5-topic-representation). However, c-TF-IDF is powered by the [CountVectorizer](https://maartengr.github.io/BERTopic/getting_started/vectorizers/vectorizers.html) which converts text into tokens. Using the CountVectorizer, we can do a number of things:
#
# * Remove stopwords
# * Ignore infrequent words
# * Increase
#
# In other words, we can preprocess the topic representations **after** documents are assigned to topics. This will not influence the clustering process in any way.
#
# Here, we will ignore English stopwords and infrequent words. Moreover, by increasing the n-gram range we will consider topic representations that are made up of one or two words.

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_model = CountVectorizer(stop_words="english",
                                   min_df=2,            # una parola specifica sarà inclusa nel vocabolario solo se compare in almeno due documenti del corpus testuale
                                   ngram_range=(1, 2))  # bigrammi

# %%
from bertopic import BERTopic

topic_model = BERTopic(

  # Pipeline models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  vectorizer_model=vectorizer_model,


  # Hyperparameters
  top_n_words=10,
  verbose=True
)

topics, probs = topic_model.fit_transform(tweets, embeddings)
# Out:
# 2023-11-14 11:48:46,661 - BERTopic - Reduced dimensionality
# 2023-11-14 11:48:55,433 - BERTopic - Clustered reduced embeddings

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1  17640                            -1_great_trump_amp_just
# 1       0   3466                0_trump_run_president_run president
# 2       1   2010                            1_obama_iran_isis_syria
# 3       2   1686                        2_thank_crowd_carolina_join
# 4       3   1200           3_entrepreneurs_think_success_think like
# 5       4   1176                        4_fake_news_fake news_media
# 6       5   1100                   5_border_wall_mexico_immigration
# 7       6   1060                    6_honor_veterans_today_families
# 8       7   1017                       7_golf_course_doral_scotland
# 9       8    970                      8_mueller_collusion_fbi_witch
# 10      9    935                          9_thanks_thank_great_nice
# 11     10    784                     10_china_trade_tariffs_chinese
# 12     11    771                 11_hotel_tower_chicago_trump tower
# 13     12    617  12_interview_interviewed_discussing_interview ...
# 14     13    601            13_obamacare_healthcare_repeal_premiums
# 15     14    580                         14_amp_great_big_amp great
# 16     15    540  15_endorsement_total endorsement_complete_comp...
# 17     16    504         16_hillary_crooked_clinton_crooked hillary
# 18     17    494               17_market_economy_stock market_stock
# 19     18    476                           18_rod_nfl_derek_players
# 20     19    466           19_impeachment_schiff_whistleblower_adam
# 21     20    410  20_celebapprentice_celebrityapprentice_season_...
# 22     21    410                          21_idea_good_thanks_enjoy
# 23     22    390                     22_election_ballots_mail_fraud
# 24     23    383   23_apprentice_celebrity apprentice_celebrity_nbc
# 25     24    380                   24_mayor_cuomo_police_anarchists
# 26     25    377               25_coronavirus_testing_virus_vaccine
# 27     26    375                             26_debt_tax_taxes_cuts
# 28     27    357  27_thanks thanks_thanks_think thanks_thanks think
# 29     28    357                        28_poll_polls_trump_numbers
# 30     29    349                   29_book_new book_read_great book
# 31     30    341                     30_twitter_tweets_tweet_haters
# 32     31    309                  31_biden_joe_joe biden_sleepy joe
# 33     32    305             32_thank thank_thank_thank law_law amp
# 34     33    293                         33_cruz_ted_rubio_ted cruz
# 35     34    293                     34_ties_macy_shirts_collection
# 36     35    259            35_wind_turbines_wind turbines_scotland
# 37     36    232                  36_donald trump_donald_trump_cpac
# 38     37    228                     37_korea_north korea_north_kim
# 39     38    198            38_democrats_party_radical left_radical
# 40     39    182                    39_melania_ivanka_lady_daughter
# 41     40    176    40_birthday_happy birthday_happy_birthday great
# 42     41    174             41_miss_pageant_universe_miss universe
# 43     42    168                  42_america_make america_make_safe
# 44     43    158                           43_gas_opec_oil_keystone
# 45     44    158           44_christmas_happy_merry christmas_merry
#
#                                        Representation  \
# 0   [great, trump, amp, just, people, thank, good,...
# 1   [trump, run, president, run president, donald,...
# 2   [obama, iran, isis, syria, iraq, president, is...
# 3   [thank, crowd, carolina, join, rally, maga, pe...
# 4   [entrepreneurs, think, success, think like, th...
# 5   [fake, news, fake news, media, cnn, story, fai...
# 6   [border, wall, mexico, immigration, security, ...
# 7   [honor, veterans, today, families, prayers, hu...
# 8   [golf, course, doral, scotland, golf course, t...
# 9   [mueller, collusion, fbi, witch, witch hunt, h...
# 28                           [thanks, thanks, thanks]
# 29  [great new poll thank you makeamericagreatagai...
# 30             [great book, a great book, great book]
# 31  [teeblack tweets business, welcome to twitter,...
# 32  [oh no the dems are worried again the only one...
# 33                  [thank you, thank you, thank you]
# 34  [endorsements for lyin ted cruz, i agree with ...
# 35  [jfordeureka love the ties where can i get the...
# 36  [like ugly bird killing wind turbines, see sto...
# 37  [via only the donald, via donald trump on who ...
# 38  [our united states team has arrived in north k...
# 39  [democrats are now the party of high taxes hig...
# 40  [hmackie melania as first lady she ll go down ...
# 41  [happy birthday, happy birthday, have a happy ...
# 42  [miss usa pageant is much better, excited to a...
# 43  [make america safe again, make america great a...
# 44  [a gallon gas and we have yet to approve the k...
# 45  [merry christmas, merry christmas, merry chris...

# %%
topic_model.get_topic(4, full=True)
# Out:
# {'Main': [('fake', 0.05387783483123264),
#   ('news', 0.0515901642438059),
#   ('fake news', 0.04983099786976331),
#   ('media', 0.048437775212879036),
#   ('cnn', 0.024812424192760342),
#   ('story', 0.02006987120003447),
#   ('failing', 0.019512568101102815),
#   ('dishonest', 0.01856382266592833),
#   ('news media', 0.017491151802953703),
#   ('reporting', 0.015595441952932597)]}

# %%
fig = topic_model.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f6beeb0f-9bb4-4dc4-9735-3a55d69af8e9" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6beeb0f-9bb4-4dc4-9735-3a55d69af8e9")) {                    Plotly.newPlot(                        "f6beeb0f-9bb4-4dc4-9735-3a55d69af8e9",                        [{"customdata":[[0,"trump | run | president | run president | donald",3466],[1,"obama | iran | isis | syria | iraq",2010],[2,"thank | crowd | carolina | join | rally",1686],[3,"entrepreneurs | think | success | think like | think big",1200],[4,"fake | news | fake news | media | cnn",1176],[5,"border | wall | mexico | immigration | security",1100],[6,"honor | veterans | today | families | prayers",1060],[7,"golf | course | doral | scotland | golf course",1017],[8,"mueller | collusion | fbi | witch | witch hunt",970],[9,"thanks | thank | great | nice | hi",935],[10,"china | trade | tariffs | chinese | deal",784],[11,"hotel | tower | chicago | trump tower | trump",771],[12,"interview | interviewed | discussing | interview discussing | enjoy",617],[13,"obamacare | healthcare | repeal | premiums | website",601],[14,"amp | great | big | amp great | better",580],[15,"endorsement | total endorsement | complete | complete total | total",540],[16,"hillary | crooked | clinton | crooked hillary | hillary clinton",504],[17,"market | economy | stock market | stock | unemployment",494],[18,"rod | nfl | derek | players | game",476],[19,"impeachment | schiff | whistleblower | adam | adam schiff",466],[20,"celebapprentice | celebrityapprentice | season | boardroom | wait",410],[21,"idea | good | thanks | enjoy | good idea",410],[22,"election | ballots | mail | fraud | voting",390],[23,"apprentice | celebrity apprentice | celebrity | nbc | season",383],[24,"mayor | cuomo | police | anarchists | portland",380],[25,"coronavirus | testing | virus | vaccine | covid",377],[26,"debt | tax | taxes | cuts | cut",375],[27,"thanks thanks | thanks | think thanks | thanks think | thank think",357],[28,"poll | polls | trump | numbers | new",357],[29,"book | new book | read | great book | books",349],[30,"twitter | tweets | tweet | haters | losers",341],[31,"biden | joe | joe biden | sleepy joe | sleepy",309],[32,"thank thank | thank | thank law | law amp | amp order",305],[33,"cruz | ted | rubio | ted